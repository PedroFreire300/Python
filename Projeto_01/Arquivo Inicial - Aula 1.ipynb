# %% [markdown]
# # Automação de Sistemas e Processos com Python
#
# ### Desafio:
#
# Todos os dias, o nosso sistema atualiza as vendas do dia anterior.
# O seu trabalho diário, como analista, é enviar um e-mail para a diretoria, assim que começar a trabalhar, com o faturamento e a quantidade de produtos vendidos no dia anterior
#
# E-mail da diretoria: seugmail+diretoria@gmail.com<br>
# Local onde o sistema disponibiliza as vendas do dia anterior: https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing
#
# Para resolver isso, vamos usar o pyautogui, uma biblioteca de automação de comandos do mouse e do teclado

# %%
import pyautogui
import time

pyautogui.PAUSE = 2

pyautogui.press("win")
pyautogui.write("chrome")
pyautogui.press("enter")

time.sleep(2)

link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga"
pyautogui.write(link)
pyautogui.press("enter")

time.sleep(2)

# %%
pyautogui.click(x=379,y=367,clicks=2)

time.sleep(2)

pyautogui.click(x=1265, y=366)

time.sleep(2)

pyautogui.click(x=1096, y=414, clicks=2)

# %% [markdown]
# ### Vamos agora ler o arquivo baixado para pegar os indicadores
#
# - Faturamento
# - Quantidade de Produtos

# %%
time.sleep(2)

import pandas

caminho = r"C:\Users\pedro\Downloads\Vendas - Dez.xlsx"
tabela = pandas.read_excel(caminho)
display(tabela)

faturamento = tabela["Valor Final"].sum()
qtde_produto = tabela["Quantidade"].sum()

print(faturamento)
print(qtde_produto)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %% [markdown]
# ### Vamos agora enviar um e-mail pelo gmail

# %%
import pyperclip

pyautogui.hotkey("ctrl","t")
pyautogui.write("https://mail.google.com/mail/u/0/#inbox)")
pyautogui.press("enter")

time.sleep(5)

pyautogui.click(x=100, y=216)

pyautogui.write("pedrofreirepro@outlook.com")
pyautogui.press("tab")
pyautogui.press("tab")

time.sleep(5)

pyperclip.copy("Relatório de Vendas")
pyautogui.hotkey("ctrl","v")

time.sleep(5)

pyautogui.press("tab")

texto = f"""

Prezados,

Segue o ralatório de vendas de hoje.

Faturmento: R${faturamento:,.2f}
Quantidade de produtos vendidos: {qtde_produto:,}

Qualquer dúvida estou á disposição

Vai Corinthians 
Deus é com d maisculo
Atensiosamente, tmj
"""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl","v")

time.sleep(7)

pyautogui.click(x=839, y=700)
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 import pyperclip
#       3 pyautogui.hotkey("ctrl","t")
# ----> 4 pyautogui.write("https://mail.google.com/mail/u/0/#inbox)")
#       5 pyautogui.press("enter")
#       7 time.sleep(5)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pyautogui\__init__.py:593, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     591 @functools.wraps(wrappedFunction)
#     592 def wrapper(*args, **kwargs):
# --> 593     failSafeCheck()
#     594     returnVal = wrappedFunction(*args, **kwargs)
#     595     _handlePause(kwargs.get("_pause", True))
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pyautogui\__init__.py:1734, in failSafeCheck()
#    1732 def failSafeCheck():
#    1733     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# ...

# %% [markdown]
# #### Use esse código para descobrir qual a posição de um item que queira clicar
#
# - Lembre-se: a posição na sua tela é diferente da posição na minha tela
