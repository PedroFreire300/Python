# %% [markdown]
# # Exercícios
#
# ## 1. Faturamento do Melhor e do Pior Mês do Ano
#
# Qual foi o valor de vendas do melhor mês do Ano?
# E valor do pior mês do ano?

# %%
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
vendas_1sem = [25000, 29000, 22200, 17750, 15870, 19900]
vendas_2sem = [19850, 20120, 17540, 15555, 49051, 9650]

lista_nova_vendas = vendas_1sem + vendas_2sem

maior_valor = max(lista_nova_vendas)
menor_valor = min(lista_nova_vendas)

print("Valor máximo foi:",(maior_valor))
print("Valor mínimo foi:",(menor_valor))
# Out:
# Valor máximo foi: 49051
# Valor mínimo foi: 9650

# %% [markdown]
# ## 2. Continuação
#
# Agora relacione as duas listas para printar 'O melhor mês do ano foi {} com {} vendas' e o mesmo para o pior mês do ano.
#
# Calcule também o faturamento total do Ano e quanto que o melhor mês representou do faturamento total.
#
# Obs: Para o faturamento total, pode usar a função sum(lista) que soma todos os itens de uma lista

# %%
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
vendas_1sem = [25000, 29000, 220200, 17750, 15870, 19900]
vendas_2sem = [19850, 20120, 17540, 15555, 49051, 960050]

lista_nova_vendas = vendas_1sem + vendas_2sem

maior_valor = max(lista_nova_vendas)
menor_valor = min(lista_nova_vendas)

i_1 = lista_nova_vendas.index(maior_valor)
i_2 = lista_nova_vendas.index(menor_valor)

print(f"O melhor mês do ano foi {meses[i_1]} com {maior_valor}")
print(f"O pior mês do ano foi {meses[i_2]} com {menor_valor}")
# Out:
# O melhor mês do ano foi dez com 960050
# O pior mês do ano foi out com 15555

# %% [markdown]
# ## 3. Crie uma lista com o top 3 valores de vendas do ano (sem fazer "no olho")
#
# Dica: o método remove retira um item da lista.

# %%
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
vendas_1sem = [25000, 29000, 22000, 17750, 15870, 19900]
vendas_2sem = [19850, 20120, 17540, 15555, 4951, 9650]

lista_nova_vendas = vendas_1sem + vendas_2sem

maior_1 = max(lista_nova_vendas)
print((maior_1))

lista_nova_vendas.remove(maior_1)

maior_2 = max(lista_nova_vendas)
print((maior_2))

lista_nova_vendas.remove(maior_2)

maior_3 = max(lista_nova_vendas)
print((maior_3))
# Out:
# 29000
# 25000
# 22000
